# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os
import glob
import shutil
#task 1 to 4 done together (oops)
mth_to_no = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

def renameddmm(files):
    newfiles=[]
    for i,file in enumerate(files):
        oldname = os.path.split(files[i])[-1]
        name = oldname.split('_')
        date = name[0].split('-')
        if date[0] in mth_to_no:
            date[0] = mth_to_no[date[0]]
        try:
            newname = f'{date[0]}-{date[1]}-{name[1]}'
            newfiles.extend([newname])
        except:
            newfiles.extend([oldname]) #assuming files are renamed correctly already
            continue
    return newfiles

#1 access files, #2 check names, #3 change names as required
#C:\Users\65889\Documents\GitHub\learning-portfolio-2024-aug-Arcen3\6.2_files,_folders_&_os__exercises\os-collaboration-exercise-data

path = os.path.join('.','os-collaboration-exercise-data')
files = glob.glob(os.path.join('os-collaboration-exercise-data','*'))
correctednames = renameddmm(files)
for i,files in enumerate(files):
    print(files)
    oldpath = os.path.join(files)
    newpath = os.path.join(path,correctednames[i])
    if oldpath!=newpath:
        os.rename(oldpath,newpath)
    else:
        continue
# Out:
# os-collaboration-exercise-data\apr-01_melbourne.pdf
# os-collaboration-exercise-data\apr-01_melbourne.png
# os-collaboration-exercise-data\apr-01_melbourne.txt
# os-collaboration-exercise-data\apr-01_shanghai.png
# os-collaboration-exercise-data\apr-01_shanghai.txt
# os-collaboration-exercise-data\apr-01_singapore.jpg
# os-collaboration-exercise-data\apr-01_singapore.txt
# os-collaboration-exercise-data\apr-02_cairo.jpg
# os-collaboration-exercise-data\apr-02_cairo.txt
# os-collaboration-exercise-data\apr-02_jakarta.png
# os-collaboration-exercise-data\apr-02_jakarta.txt
# os-collaboration-exercise-data\apr-02_karachi.pdf
# os-collaboration-exercise-data\apr-02_karachi.png
# os-collaboration-exercise-data\apr-02_karachi.txt
# os-collaboration-exercise-data\apr-02_shanghai.jpg
# os-collaboration-exercise-data\apr-02_shanghai.pdf
# os-collaboration-exercise-data\apr-02_shanghai.png
# os-collaboration-exercise-data\apr-02_shanghai.txt
# os-collaboration-exercise-data\apr-03_manila.jpg
# ...

# %%
mth_to_no = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

def rename_my_file(old_file_name):
    name = old_file_name.split('_')
    date = name[0].split('-')
    if date[0] in mth_to_no:
        date[0] = mth_to_no[date[0]]
    try:
        newname = f'{date[0]}-{date[1]}-{name[1]}'
        return newname
    except:
        return old_file_name

userin = input('Please input file name here: ')
try:
    print(rename_my_file(userin))
except:
    print('Unable to rename due to format')
# Out:
# Please input file name here:  apr-07_dhaka
# 04-07-dhaka

# %%
files=['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']
renamed=[]
for i,files in enumerate(files):
    renamed.append(rename_my_file(files)) #an f string is returned here, why does this not cause .extend to iterate through the string?
    print(f'{files} ------> {renamed[i]}')

print(renamed)
#its because of the [], assigns the f string as ONE element and is NOT iterable. Hence .extend adds it to the list as a non-iterable.
# Out:
# oct-08_singapore.txt ------> 10-08-singapore.txt
# jul-10_cairo.txt ------> 07-10-cairo.txt
# may-15_dhaka.txt ------> 05-15-dhaka.txt
# may-13_cairo.txt ------> 05-13-cairo.txt
# oct-21_cairo.txt ------> 10-21-cairo.txt
# jan-10_singapore.txt ------> 01-10-singapore.txt
# jun-20_tokyo.txt ------> 06-20-tokyo.txt
# aug-06_jakarta.txt ------> 08-06-jakarta.txt
# dec-21_karachi.txt ------> 12-21-karachi.txt
# jan-01_tokyo.txt ------> 01-01-tokyo.txt
# ['10-08-singapore.txt', '07-10-cairo.txt', '05-15-dhaka.txt', '05-13-cairo.txt', '10-21-cairo.txt', '01-10-singapore.txt', '06-20-tokyo.txt', '08-06-jakarta.txt', '12-21-karachi.txt', '01-01-tokyo.txt']

# %%
countries = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for country in countries:
    try:
        os.mkdir(os.path.join(path,country))
        print('Creating', country)
    except FileExistsError:
        print('Skipping', country)
# Out:
# Creating Cairo
# Creating Dhaka
# Creating Jakarta
# Creating Karachi
# Creating Manila
# Creating Melbourne
# Creating Osaka
# Creating Shanghai
# Creating Singapore
# Creating Tokyo

# %%
cairo=glob.glob(os.path.join('os-collaboration-exercise-data','*cairo.*'))
#cairo2=glob.glob(os.path.join('os-collaboration-exercise-data','*cairo*'))
print(len(cairo))
#print(len(cairo1), len(cairo2))
i=0
for file in cairo:
    i+=1
    ptd = os.path.join('.','os-collaboration-exercise-data','Cairo')
    ext = os.path.splitext(file)[-1]
    shutil.copy(file, ptd)
    #print('Copy', file, 'to', ptd)
print(i)
# Out:
# 275
# 275

# %%
import glob
import os
import shutil

countries = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for country in countries: #this was for after i delete files to retest the script
    try:
        os.mkdir(os.path.join(path,country))
        print('Creating', country)
    except FileExistsError:
        print('Skipping', country)
print('----------------------')

def copy_into_folder(country_name,files_for_folder):
    i,j=0,0
    print("files to copy:", len(files_for_folder))
    ptd = os.path.join('.','os-collaboration-exercise-data',country_name)
    for file in files_for_folder:
        try: #if file!=ptd:
            shutil.move(file, ptd)
            i+=1
            #print(f'move {file} to {ptd}')
        except: #else
            j+=1
            continue
    print('files copied: ', i, '\nfiles already present: ', j, '\n-------------')

for country in countries:
    print('Starting copy for ', country)
    files_for_folder=glob.glob(os.path.join('.','os-collaboration-exercise-data', '*'+country+'.*'))
    copy_into_folder(country,files_for_folder)

print('File copying completed')
# Out:
# Skipping Cairo
# Skipping Dhaka
# Skipping Jakarta
# Skipping Karachi
# Skipping Manila
# Skipping Melbourne
# Skipping Osaka
# Skipping Shanghai
# Skipping Singapore
# Skipping Tokyo
# ----------------------
# Starting copy for  Cairo
# files to copy: 7
# files copied:  0
# files already present:  7
# -------------
# Starting copy for  Dhaka
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Jakarta
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Karachi
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Manila
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Melbourne
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Osaka
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# ...

# %%
import glob
import os
import shutil

countries = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

for country in countries: #this was for after i delete files to retest the script
    try:
        os.mkdir(os.path.join(path,country))
        print('Creating', country)
    except FileExistsError:
        print('Skipping', country)
print('----------------------')

def copy_into_folder(country_name,files_for_folder):
    i,j=0,0
    print("files to copy:", len(files_for_folder))
    ptd = os.path.join('.','os-collaboration-exercise-data',country_name)
    for file in files_for_folder:
        #print(file, ptd)
        file_name=os.path.split(file)[1]
        #print(file_name)
        #print(os.path.join(ptd,file_name))
        if os.path.exists(os.path.join(ptd, file_name))==False:
            shutil.move(file, ptd)
            i+=1
            #print(f'move {file} to {ptd}')
        else:
            j+=1
            continue
    print('files copied: ', i, '\nfiles already present: ', j, '\n-------------')

for country in countries:
    print('Starting copy for ', country)
    files_for_folder=glob.glob(os.path.join('.','os-collaboration-exercise-data', '*'+country+'.*'))
    copy_into_folder(country,files_for_folder)

print('File copying completed')
#potato potato
# Out:
# Skipping Cairo
# Skipping Dhaka
# Skipping Jakarta
# Skipping Karachi
# Skipping Manila
# Skipping Melbourne
# Skipping Osaka
# Skipping Shanghai
# Skipping Singapore
# Skipping Tokyo
# ----------------------
# Starting copy for  Cairo
# files to copy: 9
# files copied:  0
# files already present:  9
# -------------
# Starting copy for  Dhaka
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Jakarta
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Karachi
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Manila
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Melbourne
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# Starting copy for  Osaka
# files to copy: 0
# files copied:  0
# files already present:  0
# -------------
# ...
